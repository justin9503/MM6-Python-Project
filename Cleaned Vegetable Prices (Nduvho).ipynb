# %%
import pandas as pd

# %%
pd.read_csv('C:\Users\HP\Documents\Work 2023\AI Academy\AI Explore\Python\Project\prices.csv')
# Out:
#     Price Dates  Bhindi (Ladies finger)  Tomato  Onion  Potato  Brinjal  \
# 0    01-01-2023                    35.0      18   22.0      20       30
# 1    02-01-2023                    35.0      16   22.0      20       30
# 2    03-01-2023                    35.0      16   21.0      20       30
# 3    04-01-2023                    30.0      16   21.0      22       25
# 4    08-01-2023                    35.0      16   20.0      21       25
# 5    11-01-2023                    35.0      16   18.0      24       25
# 6    12-01-2023                    40.0      16   18.0      22       30
# 7    15-01-2023                    42.0      16   17.0      22       25
# 8    17-01-2023                    35.0      16   18.0      22       30
# 9    22-01-2023                    45.0      16   18.0      22       40
# 10   23-01-2023                    42.0      16   18.0      22       50
# 11   24-01-2023                    45.0      16   16.0      22       60
# ...

# %%
Vegetable_prices = pd.read_csv('C:\Users\HP\Documents\Work 2023\AI Academy\AI Explore\Python\Project\prices.csv')

# %%
Vegetable_prices.head()
# Out:
#   Price Dates  Bhindi (Ladies finger)  Tomato  Onion  Potato  Brinjal  Garlic  \
# 0  01-01-2023                    35.0      18   22.0      20       30      50
# 1  02-01-2023                    35.0      16   22.0      20       30      55
# 2  03-01-2023                    35.0      16   21.0      20       30      55
# 3  04-01-2023                    30.0      16   21.0      22       25      55
# 4  08-01-2023                    35.0      16   20.0      21       25      55
#
#    Peas  Methi  Green Chilli  Elephant Yam (Suran)
# 0    25      8          45.0                    25
# 1    25      7          40.0                    25
# 2    25      7          40.0                    25
# 3    25      7          40.0                    25
# 4    22      6          35.0                    25

# %%
#Convert all data in column 'Price Dates' to Date type.

Price_Date = list(Vegetable_prices['Price Dates']) 

Price_Date = pd.to_datetime(Vegetable_prices["Price Dates"])

# %%
#Convert all data in column 'Bhindi (Ladies finger)' to float datatype.

Bhindi_Ladies_Finger = list(Vegetable_prices['Bhindi (Ladies finger)'])

Bhindi_Ladies_Finger = Vegetable_prices['Bhindi (Ladies finger)'].astype(float)

# %%
#Convert all data in column 'Tomatoes' to int datatype

Tomatoes = list(Vegetable_prices['Tomato'])

Tomatoes = Vegetable_prices['Tomato'].astype(int)

# %%
#Convert all data in column 'Onion' to float datatype.

Onions = list(Vegetable_prices['Onion'])

Onions = Vegetable_prices['Onion'].astype(float)

# %%
#Convert all data in column 'Potato' to datatype: int

Potatoes = list(Vegetable_prices['Potato'])

Potatoes = Vegetable_prices['Potato'].astype(int)

# %%
#Convert all data in coloumn 'Brinjales' to datatype: int

Brinjales = list(Vegetable_prices['Brinjal'])

Brinjales = Vegetable_prices['Brinjal'].astype(int)

# %%
#Convert all data in column 'Garlic' to datatype: int

garlic = list(Vegetable_prices['Garlic'])

garlic = Vegetable_prices['Garlic'].astype(int)

# %%
#Convert all data in column 'Peas' to datatype: int

peas = list(Vegetable_prices['Peas'])

peas = Vegetable_prices['Peas'].astype(int)

# %%
#Convert all data in column 'Methi' to datatype: int


Methis = list(Vegetable_prices['Methi'])

Methis = Vegetable_prices['Methi'].astype(int)

# %%
#Convert all data in column 'Green Chilli' to float type.

Green_Chillis = list(Vegetable_prices['Green Chilli'])

Green_Chillis = Vegetable_prices['Green Chilli'].astype(float)

# %%
#Convert all data in column 'Elephant Yam (Suran)' to int data type.

Elephant_Yam_Suran = list (Vegetable_prices['Elephant Yam (Suran)'])

Elephant_Yam_Suran = Vegetable_prices['Elephant Yam (Suran)'].astype(int)
